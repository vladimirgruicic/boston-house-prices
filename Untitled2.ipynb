# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [0.76189408 0.62548542 0.73628246 0.78165212 0.67528099]
# Mean Cross-Validation R-squared Score: 0.716119015752365
#
# Baseline Mean Squared Error (MSE): 75.04543037399255
# Baseline R-squared: -0.023340500652033302
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 24.962338805773474
# R-squared on Test Data: 0.6596065588052291
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [ 0.5732169   0.78012221  0.5090022  -0.17201048  0.32743644]
# Mean Cross-Validation R-squared Score: 0.40355345335559384
#
# Baseline Mean Squared Error (MSE): 86.39958329824562
# Baseline R-squared: -8.769772687156063e-06
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 35.136317329687266
# R-squared on Test Data: 0.5933241327575156
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [0.76676506 0.73591682 0.77907982 0.71562396 0.60192749]
# Mean Cross-Validation R-squared Score: 0.7198626305647694
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 26.157954033902097
# R-squared on Test Data: 0.6775808115870409
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [0.65390947 0.69187411 0.7485787  0.75198345 0.68193383]
# Mean Cross-Validation R-squared Score: 0.7056559157311496
#
# Baseline Mean Squared Error (MSE): 65.00802631111615
# Baseline R-squared: -0.04122432859876257
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 14.501552541136055
# R-squared on Test Data: 0.7677306916530378
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [ 0.12958683 -0.59166036 -1.12256439  0.0692981  -0.29308364]
# Mean Cross-Validation R-squared Score: -0.36168469256308977
#
# Baseline Mean Squared Error (MSE): 84.30086985446987
# Baseline R-squared: -0.0002844989488024474
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 46.96480202383131
# R-squared on Test Data: 0.44273216229278456
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [0.6453458  0.74124648 0.68987451 0.75860182 0.68889241]
# Mean Cross-Validation R-squared Score: 0.7047922020751168
#
# Baseline Mean Squared Error (MSE): 76.52974667801816
# Baseline R-squared: -0.08922237119047804
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 14.859987141240701
# R-squared on Test Data: 0.7885027570006147
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [0.76676506 0.73591682 0.77907982 0.71562396 0.60192749]
# Mean Cross-Validation R-squared Score: 0.7198626305647694
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 26.157954033902097
# R-squared on Test Data: 0.6775808115870409
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.p
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/IPython/core/magics/execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'ridge-model-boston-housing.p'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('run', 'ridge-model-boston-housing.p')
#
# File /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/IPython/core/magics/execution.py:727, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     725     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     726         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 727     raise Exception(msg) from e
#     728 except TypeError:
#     729     if fpath in sys.meta_path:
#
# Exception: File `'ridge-model-boston-housing.p'` not found.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [-0.32592959  0.88645511  0.88732387  0.63041126  0.78681753]
# Mean Cross-Validation R-squared Score: 0.5730156391225849
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 28.593165712196928
# R-squared on Test Data: 0.6475647418320452
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [-54.1573353    0.73025584   0.55426069  -0.07693987   0.14937411]
# Mean Cross-Validation R-squared Score: -10.560076905417304
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 254.6094838017451
# R-squared on Test Data: -2.1382799672790482
# Baseline outperforms ridge model.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [-0.75984913  0.84656197  0.92153866  0.69685323  0.82147003]
# Mean Cross-Validation R-squared Score: 0.505314952376459
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 17.610665715885606
# R-squared on Test Data: 0.7829334610738764
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]
# Cross-Validation R-squared Scores: [0.77763397 0.75778979 0.78396139 0.72703958 0.57209825]
# Mean Cross-Validation R-squared Score: 0.7237045952417012
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 25.182006363393818
# R-squared on Test Data: 0.6896102025497659
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.85433336 0.89765161 0.86658117 0.811887   0.83716891]
# Mean Cross-Validation R-squared Score: 0.8535244086262249
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 16.42282680925343
# R-squared on Test Data: 0.7975745930119982
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.7776781  0.7578735  0.78380838 0.72682278 0.57196757]
# Mean Cross-Validation R-squared Score: 0.7236300656603197
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 25.17870574735873
# R-squared on Test Data: 0.689650885469459
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.80353142 0.89673398 0.85906476 0.80412341 0.85286843]
# Mean Cross-Validation R-squared Score: 0.8432643984735064
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 17.31724558211776
# R-squared on Test Data: 0.7865501155442849
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [-1.73051674  0.81815838  0.90999033  0.63941378  0.8129384 ]
# Mean Cross-Validation R-squared Score: 0.28999682845181135
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 19.44995995188857
# R-squared on Test Data: 0.7602625842133957
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [-10.06283716   0.77834708   0.76521815   0.40829232   0.66294309]
# Mean Cross-Validation R-squared Score: -1.4896073053389018
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 43.104371382549765
# R-squared on Test Data: 0.4687017027325475
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [-33.71670795   0.74872195   0.58989649   0.13585822   0.26890486]
# Mean Cross-Validation R-squared Score: -6.3946652871998095
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 107.3116957950539
# R-squared on Test Data: -0.32270856583879004
# Baseline outperforms ridge model.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.77731132 0.7571426  0.78510605 0.72859442 0.57312814]
# Mean Cross-Validation R-squared Score: 0.7242565085016036
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 25.20788589620435
# R-squared on Test Data: 0.6892912151414057
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.90003652 0.89223061 0.87828885 0.8136572  0.77423659]
# Mean Cross-Validation R-squared Score: 0.8516899542035118
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 15.482056508046805
# R-squared on Test Data: 0.8091703927677791
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.84114353 0.90390982 0.91240697 0.80255651 0.81795263]
# Mean Cross-Validation R-squared Score: 0.8555938928086853
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 15.857111213400279
# R-squared on Test Data: 0.8045475222805154
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.00769896 0.89737092 0.92187258 0.72244453 0.82845255]
# Mean Cross-Validation R-squared Score: 0.6755679099977829
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 18.37577237980964
# R-squared on Test Data: 0.773502866107924
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [-1.58536871  0.87732741  0.88387576  0.60623754  0.78401973]
# Mean Cross-Validation R-squared Score: 0.3132183454973059
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 24.57777706979973
# R-squared on Test Data: 0.6970578461308904
# Ridge model outperforms baseline.

# %%
# %run ridge-model-boston-housing.py
# Out:
# Cross-Validation R-squared Scores: [0.89032643 0.90685669 0.90558902 0.80864741 0.80171243]
# Mean Cross-Validation R-squared Score: 0.862626396301209
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Ridge Regression with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 15.916276357544094
# R-squared on Test Data: 0.8038182612025098
# Ridge model outperforms baseline.
