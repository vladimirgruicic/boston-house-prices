# %%
# %run ridge-grid-search-model-boston-housing.py
# Out:
# Best Alpha:  5.0
# Cross-Validation R-squared Scores: [0.89032643 0.90685669 0.90558902 0.80864741 0.80171243]
# Mean Cross-Validation R-squared Score: 0.862626396301209
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Best Ridge Regression Model with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 15.916276357544094
# R-squared on Test Data: 0.8038182612025098
# Best Ridge model outperforms baseline.

# %%
# %run ridge-grid-search-model-boston-housing.py
# Out:
# Best Alpha:  5.0
# Cross-Validation R-squared Scores: [0.89032643 0.90685669 0.90558902 0.80864741 0.80171243]
# Mean Cross-Validation R-squared Score: 0.862626396301209
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Best Ridge Regression Model with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 15.916276357544094
# R-squared on Test Data: 0.8038182612025098
# Best Ridge model outperforms baseline.

# %%
# %run ridge-grid-search-model-boston-housing.py
# Out:
# Best Alpha:  5.0
# Cross-Validation R-squared Scores: [0.89032643 0.90685669 0.90558902 0.80864741 0.80171243]
# Mean Cross-Validation R-squared Score: 0.862626396301209
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Best Ridge Regression Model with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 15.916276357544094
# R-squared on Test Data: 0.8038182612025098
# Best Ridge model outperforms baseline.

# %%
# %run ridge-grid-search-model-boston-housing.py
# Out:
# Best Alpha:  5.0
# Cross-Validation R-squared Scores: [0.89032643 0.90685669 0.90558902 0.80864741 0.80171243]
# Mean Cross-Validation R-squared Score: 0.862626396301209
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
#
# Best Ridge Regression Model with Scaled Features:
# Mean Squared Error (MSE) on Test Data: 15.916276357544094
# R-squared on Test Data: 0.8038182612025098
# Best Ridge model outperforms baseline.

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.771e+02, tolerance: 1.784e+00
#   model = cd_fast.enet_coordinate_descent(
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.649e+02, tolerance: 1.652e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.329e+01, tolerance: 1.784e+00
#   model = cd_fast.enet_coordinate_descent(
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.603e+01, tolerance: 1.652e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.453e+02, tolerance: 1.784e+00
#   model = cd_fast.enet_coordinate_descent(
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.193e+02, tolerance: 1.652e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/elastic-net-model-boston-housing.py:59
#      53 param_grid = {
#      54     'alpha': [0.1, 0.5, 1.0, 3.0, 4.0, 5.0, 10.0, 20.0],
#      55     'l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9]
#      56              }
#      58 # Initialize the Elastic Net CV model with different solvers and normalization
# ---> 59 elastic_net_model = ElasticNetCV(l1_ratio=[.1, .5, .7, .9, .95, .99, 1], alphas=[0.1, 0.5, 1.0, 3.0, 5.0, 10.0], max_iter=10000, cv=5, normalize=True)
#      61 # Fit the Elastic Net CV model to the data
#      62 elastic_net_model.fit(X_train_scaled, y_train)
#
# TypeError: ElasticNetCV.__init__() got an unexpected keyword argument 'normalize'

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.572e+01, tolerance: 1.784e+00
#   model = cd_fast.enet_coordinate_descent(
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.822e+01, tolerance: 1.652e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# %run elastic-net-model-boston-housing.py

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# Best Alpha: 0.1
# Best L1 Ratio: 0.1
# Mean Squared Error (MSE) on Test Data: 25.755052219175653
# R-squared on Test Data: 0.6825469215490756
# Cross-Validation R-squared Scores: [0.76080771 0.74731628 0.79221832 0.73364068 0.58929092]
# Mean Cross-Validation R-squared Score: 0.7246547807028852
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
# Best Ridge model outperforms baseline.

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# Best Alpha: 0.1
# Best L1 Ratio: 1.0
# Mean Squared Error (MSE) on Test Data: 20.289746604320555
# R-squared on Test Data: 0.7499114944237955
# Cross-Validation R-squared Scores: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score: 0.8224005672759034
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
# Best Ridge model outperforms baseline.

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.572e+01, tolerance: 1.784e+00
#   model = cd_fast.enet_coordinate_descent(
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.822e+01, tolerance: 1.652e+00
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# Best Alpha: 0.1
# Best L1 Ratio: 1.0
# Mean Squared Error (MSE) on Test Data: 20.260179935176403
# R-squared on Test Data: 0.7502759289455925
# Cross-Validation R-squared Scores: [0.90352858 0.89956219 0.87273094 0.83618136 0.74763664]
# Mean Cross-Validation R-squared Score: 0.8519279452377724
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
# Best Ridge model outperforms baseline.

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.87537902043732, tolerance: 1.78373798019802
#   model = cd_fast.enet_coordinate_descent_gram(
# /mnt/d/Projects/machine-learning/predictive-modeling/boston-house-prices/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6964269317659273, tolerance: 1.6516362425742575
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# Best Alpha: 0.1
# Best L1 Ratio: 1.0
# Mean Squared Error (MSE) on Test Data: 20.289746604320555
# R-squared on Test Data: 0.7499114944237955
# Cross-Validation R-squared Scores: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score: 0.8224005672759034
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
# Best Ridge model outperforms baseline.

# %%
# %run elastic-net-model-boston-housing.py
# Out:
# Best Alpha: 0.1
# Best L1 Ratio: 1.0
# Mean Squared Error (MSE) on Test Data: 20.289746604320555
# R-squared on Test Data: 0.7499114944237955
# Cross-Validation R-squared Scores: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score: 0.8224005672759034
#
# Baseline Mean Squared Error (MSE): 81.31656079613805
# Baseline R-squared: -0.002296261490632334
# Best Ridge model outperforms baseline.

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# Mean Cross-Validation R-squared Score for CRIM: 0.5745732254441054
# Best Ridge model outperforms baseline for MEDV.
# Best Ridge model outperforms baseline for CRIM.

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# Mean Cross-Validation R-squared Score for CRIM: 0.5745732254441054
# Best Ridge model outperforms baseline for MEDV.
# Best Ridge model outperforms baseline for CRIM.

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# Mean Cross-Validation R-squared Score for CRIM: 0.5745732254441054
# Best Ridge model outperforms baseline for MEDV.
# Best Ridge model outperforms baseline for CRIM.

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
# Best Alpha for CHAS: 0.5
# Best L1 Ratio for CHAS: 0.1
# Mean Squared Error (MSE) on Test Data for CHAS: 0.06452575170864597
# R-squared on Test Data for CHAS: 0.02358656238328105
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# Mean Cross-Validation R-squared Score for CRIM: 0.5745732254441054
#
# Cross-Validation R-squared Scores for CHAS: [ 0.0290967  -0.04872951  0.02950053 -0.39288931  0.02827052]
# ...

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Best Alpha for CHAS: 0.5
# Best L1 Ratio for CHAS: 0.1
# Mean Squared Error (MSE) on Test Data for CHAS: 0.06452575170864597
# R-squared on Test Data for CHAS: 0.02358656238328105
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# Mean Cross-Validation R-squared Score for CRIM: 0.5745732254441054
#
# ...

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Best Alpha for CHAS: 0.5
# Best L1 Ratio for CHAS: 0.1
# Mean Squared Error (MSE) on Test Data for CHAS: 0.06452575170864597
# R-squared on Test Data for CHAS: 0.02358656238328105
# Best Alpha for ZN: 0.1
# Best L1 Ratio for ZN: 1.0
# Mean Squared Error (MSE) on Test Data for ZN: 136.98501479398524
# R-squared on Test Data for ZN: 0.7349521960964768
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# ...

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Best Alpha for CHAS: 0.5
# Best L1 Ratio for CHAS: 0.1
# Mean Squared Error (MSE) on Test Data for CHAS: 0.06452575170864597
# R-squared on Test Data for CHAS: 0.02358656238328105
# Best Alpha for ZN: 0.1
# Best L1 Ratio for ZN: 1.0
# Mean Squared Error (MSE) on Test Data for ZN: 136.98501479398524
# R-squared on Test Data for ZN: 0.7349521960964768
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# ...

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Best Alpha for CHAS: 0.5
# Best L1 Ratio for CHAS: 0.1
# Mean Squared Error (MSE) on Test Data for CHAS: 0.06452575170864597
# R-squared on Test Data for CHAS: 0.02358656238328105
#
# Best Alpha for ZN: 0.1
# Best L1 Ratio for ZN: 1.0
# Mean Squared Error (MSE) on Test Data for ZN: 136.98501479398524
# R-squared on Test Data for ZN: 0.7349521960964768
#
# Cross-Validation R-squared Scores for MEDV: [0.89106276 0.84085166 0.85251269 0.81114477 0.71643097]
# Mean Cross-Validation R-squared Score for MEDV: 0.8224005672759034
#
# Cross-Validation R-squared Scores for CRIM: [0.24485802 0.80004301 0.59547306 0.62949899 0.60299305]
# ...

# %%
# %run elastic-net-model-boston-housing-crim-medv.py
# Out:
# Best Alpha for MEDV: 0.1
# Best L1 Ratio for MEDV: 1.0
# Mean Squared Error (MSE) on Test Data for MEDV: 20.289746604320555
# R-squared on Test Data for MEDV: 0.7499114944237955
#
# Best Alpha for CRIM: 0.1
# Best L1 Ratio for CRIM: 0.1
# Mean Squared Error (MSE) on Test Data for CRIM: 38.7313398129634
# R-squared on Test Data for CRIM: 0.5184849183808102
#
# Best Alpha for CHAS: 0.5
# Best L1 Ratio for CHAS: 0.1
# Mean Squared Error (MSE) on Test Data for CHAS: 0.06452575170864597
# R-squared on Test Data for CHAS: 0.02358656238328105
#
# Best Alpha for ZN: 0.1
# Best L1 Ratio for ZN: 1.0
# Mean Squared Error (MSE) on Test Data for ZN: 136.98501479398524
# R-squared on Test Data for ZN: 0.7349521960964768
# Best Alpha for ZN: 0.1
# Best L1 Ratio for ZN: 1.0
# Mean Squared Error (MSE) on Test Data for ZN: 136.98501479398524
# R-squared on Test Data for ZN: 0.7349521960964768
# Best Alpha for RM: 0.1
# Best L1 Ratio for RM: 0.1
# ...
